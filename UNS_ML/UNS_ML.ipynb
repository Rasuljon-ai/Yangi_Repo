# %% [markdown]
# # Unsepervised Machine Learning

# %% [markdown]
# # ML turlari
# - Supervised
# - Unsupervised
# - Reinforcement

# %% [markdown]
# # Supervised ML da - input va output data berilishi kerak, Asosiy xususiyati berilgan malumotlar tarixiga ko`ra yangi xususiyat uchun qiymatni predict qiladi.

# %% [markdown]
# # Unsupervised ML - bunda faqat input beriladi, Asosiy qiladigan ishi guruhlash, Misol: Magazinda nechta xil turdagi mahsulot bor, Mevalar, Shirinlikalr , Sabzavot, oyinchoqlar

# %% [markdown]
# # Reinforcement ML - bunda faqatgina qaror qabul qiladi, predict qimaydi guruhlamyudi Misol uchun : tesla Avtopilot

# %% [markdown]
# # UNS ML va SML ga real misol (Analog)

# %% [markdown]
# # Sharti Kitoblarni tartiblash

# %% [markdown]
# # UNS ML :
# - Barcha kitoblarga qarab chiqamiz va ularning xususiyatiga ko`ra qanday guruhga ajratishni aniqlaymiz va darxol ularni n ta guruhga ajratamiz
# - xajmi
# - yonalishi
# - davlati
# - qolgan xususiyatlarga qarab
#
# # SML:
# - bizda guruhlarga ajratilgan kitoblar bor
# - yordamchi odamga yangi kitoblar keldi shu insonga bu kitoblarni qanday gurhlarga mosl ekanini predict qilib beradi, va har bitta kitobni o`zi o`rniga aniq  qo`yichga yordam beradi
# - yordamchiga ko`maklashish bilan modelimiz aniq natijalarni beradi va ishni vaqtni tezlikni oshiradi

# %% [markdown]
# # ML
# - SML
# - UNSML
#
# # SML
# - Classification
# - Regression
#
# # UNS ML
# - Clustering
# - Dimensionality Reduction
# - Anomaly Detection

# %% [markdown]
# # UNS ML Algaritmlari

# %% [markdown]
# # Clustering Algaritmlar

# %% [markdown]
# # 1

# %% [markdown]
# # K Means
# - Centorid asosida ishlaydi
# - k ni oldindan beriladi
# - tez va sodda
# - katta daasetlar uchun qulay
#
# # Ishlash prinsipi
# - k ta markaz tanlanadi
# - nuqtalar yaqin markazlardga biriktiriladi
# - markazlar yangilanadi
# - konvergensiyagacha takrorlanadi

# %% [markdown]
# # 2

# %% [markdown]
# # k Medoids (PAM)
# - k meansga o`xshab ishlaydi
# - centroid o`rniga real nuqta ishlatiladi
# - outlierlarga chidamli

# %% [markdown]
# # 3

# %% [markdown]
# # Hierarchical Clustering
# - ikki xil turda ish olib boradi
# - 1-turi Agglomerative (bottom-up = pastdan tepaga)
# - har nuqta alohida cluster
# - eng yaqin clusterlar birlashtilriladi
# - dendrogram hosil qilinadi
# - 2-turi Divisive (top- bottom == tepadan pastga)
# - bitta cluster
# - bo`linib boradi

# %% [markdown]
# # 4

# %% [markdown]
# # DBSCAN (Density - Based Spatial Clustering)
# - zichlik asosida ishlaydi
# - k oldindan berilmaydi
# - outlierni o`zi aniqlaydi
#
# ## parametrlari
# - eps (radius)
# - min_samples

# %% [markdown]
# # 5

# %% [markdown]
# # HDBSCAN
# - DBSCVAN ning yaxshilangan turi
# - avtomatik zichlik darajasini aniqlaydi

# %% [markdown]
# # 6

# %% [markdown]
# # Mean Shift
# - zichlik markazini siljitib boradi
# - k kerak emas
# - sekin ishlaydi

# %% [markdown]
# # 7

# %% [markdown]
# # Guassian Mixture Model (GMM)
# - probabilistic clustering
# - har nuqta ehtimollik asosiga tegishli
# - EM algoritmi ishlatiladi

# %% [markdown]
# # 8

# %% [markdown]
# # Spectral Clustering
# - Grafik asosida ishlaydi
# - Nonlinear shaklllarni topa oladi

# %% [markdown]
# # 9

# %% [markdown]
# # OPTICS
# - DBSCAN ga o`xshash
# - turli zichlikdagi clusterlarni aniqlaydi

# %% [markdown]
# # Dimensionality Reduction Algaritmlari

# %% [markdown]
# # 1

# %% [markdown]
# # PCA - Principial Component Analysis
# - linear
# - variance maksimal saqlaydi
# - eigenvalue asosida

# %% [markdown]
# # 2

# %% [markdown]
# # Kernel PCA
# - PCA ning nonlinear versiyasi
# - Kernel trick ishlatadi

# %% [markdown]
# # 3

# %% [markdown]
# # LDA - Linear Discriminant Anlaysis
# - Supervised reduction
# - Klasslarni maksimal ajratadi

# %% [markdown]
# # 4

# %% [markdown]
# # t-SNE (t-Distributed Stochastic Neigbour Embedding)
# - vizualization uchun
# - lokal struktura saqlaydi
# - sekin ishlaydi

# %% [markdown]
# # 5

# %% [markdown]
# # UMAP - Iniform Manifold Approximation and projection
# - t -SNE dan tezroq
# - global va lokal struktura saqlaydi

# %% [markdown]
# # 6

# %% [markdown]
# # SVD - Singular Value Decomposition
# - Matrix factorization
# - NLP va recommendation tizimlarda ishlaydi

# %% [markdown]
# # 7

# %% [markdown]
# # ICA - Independent Component Analysis
# - Mustaqil komponentlarni topadi
# - signal prosessingda ishlatiladi

# %% [markdown]
# # 8

# %% [markdown]
# # Autoencoder
# - Neural Networkl asosida
# - DL reduction
# - Encoder - > bottleneck -> decoder

# %% [markdown]
# # Anomaly Detection Algaritmlari

# %% [markdown]
# # 1

# %% [markdown]
# # Isolation forest
# - daraxt asosida
# - anomalyni tez ajratadi
# - eng mashxur

# %% [markdown]
# # 2

# %% [markdown]
# # Local Outlier Factor (LOF)
# - Lokal zichlikni tekshiradi
# - Qoshnilar bilan taqqoslaydi

# %% [markdown]
# # 3

# %% [markdown]
# # One - Class SVM
# - normal malumotni o`rganadi
# - chegaradan tashqarini anomlay deb xisoblaydi

# %% [markdown]
#  # 4

# %% [markdown]
# # Elliptic Envelope
# - guassian taxmin asosida
# - statik usul

# %% [markdown]
# # 5

# %% [markdown]
# # Autoencoder (DL)
# - rekonstruksiya xatosi asosida
# - katta xato - anomaly

# %% [markdown]
# # 6

# %% [markdown]
# # DBSCAN (anmaly sifatida)
# - shovqinli nuqtalar --> anomaly

# %% [markdown]
# # 7

# %% [markdown]
# # KNN based outlier Detection
# - qoshni masofa asosida
# - uzoq nuqta - anomaly

# %% [markdown]
# | Yo‘nalish  | Algoritm turi   | Linear | Outlierga chidamli | K kerak |
# | ---------- | --------------- | ------ | ------------------ | ------- |
# | Clustering | K-Means         | ✔      | ❌                  | ✔       |
# | Clustering | DBSCAN          | ❌      | ✔                  | ❌       |
# | Dim Red    | PCA             | ✔      | ❌                  | ❌       |
# | Dim Red    | UMAP            | ❌      | ✔                  | ❌       |
# | Anomaly    | IsolationForest | ❌      | ✔                  | ❌       |
# | Anomaly    | OneClassSVM     | ✔      | ❌                  | ❌       |

# %% [markdown]
# # Haqiqiy Jarayonda eng ko`p ishlatiladigan Algaritmlar
# - Clustering == K means // DBSCAN // GMM
# - Dim Red == PCA // UMAP // Autoencoder
# - Ano Det == Isolation Forest // LOF // Autoencoder
