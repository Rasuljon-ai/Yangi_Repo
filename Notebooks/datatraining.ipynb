# %% [markdown]
# # Dataset ga qo`yilgan talablar

# %% [markdown]
# # 5 ta talabga javob beradigan dataset bo`lishi kerak
# 1) Structured
# 2) To`liq
# 3) Katta
# 4) Soxaga aloqador bo`lishi
# 5) Ishonchli

# %% [markdown]
# # Process

# %% [markdown]
# - Datani input va output qismlarga ajratiladi
# - Datani Training / testing / validation qismlarga bo`linadi
# - muammo turiga qarab mos algaritm tanlanadi
# - tanlab olingan model va ajratib olingan tarining dataset bilan model o`qitiladi
# - metriklar yordamida natijalar o`lchanadi
