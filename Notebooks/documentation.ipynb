# %% [markdown]
# # Fayl ReadMe.md si haqida

# %% [markdown]
# # md fayl bu MARKDOWN formati bo`lib bu asosan strukturali matnlar, oson o`qilishi kerak bo`lgan formatlar jamlanmasi

# %% [markdown]
# # md  formati asosan qayerlarda ishlatiladi
# - dokumentatsiyada
# - blog postlarda
# - ReadMe yozganda
# - boshqa matnli hujjatlarni yozishda

# %% [markdown]
# # Formatlash belgilari
#
# #  bitta # bo`lsa 1-darajali sarlavha
# # ikkita ## bo`lsa 2-darajali sarlavha hisoblanadi

# %% [markdown]
# # Sarlavha - 1

# %% [markdown]
# ## sarlavha 2

# %% [markdown]
# # * yoki _ bu kursiv yozvuni xosil qiladi

# %% [markdown]
# *olma*

# %% [markdown]
# _qulupnay_

# %% [markdown]
# # ** bo`lsa bu qalin matn BOLD

# %% [markdown]
# **mening ismim**

# %% [markdown]
# # - yoki * qo`yish ketma ketlikni bildiradi

# %% [markdown]
# - bir
# - ikki
# - uch
#
# * olam
# * nok
# * anor

# %% [markdown]
# # `pritn()` - bu belgi kod yoki kamandalarni blegilash

# %% [markdown]
# `print("Hello World")`

# %% [markdown]
# # ![alt text](link) - bu rasm qo`yish joyi

# %% [markdown]
# ![Logo](https://example.com/logo.png)

# %% [markdown]
# # Loyihaning ReadME.md fayli quyidagi qismlardan tashkil topghan bo`lishi kerak
#
# - Loyiha nomi va qisqacha tarifi
#
# # 1) Project Name haqida
# Qisqacha loyiha haqida izoh. Masalan: “Bu loyiha ML modelini avtomatik o‘rgatish uchun yaratilgan.”
#
# #  2) Status / Badge (ixtiyoriy) haqida
# - Build status, test coverage, license kabi “badges” qo‘yish mumkin:
#
# - ![Build](https://img.shields.io/badge/build-passing-brightgreen)
#
#
# #  2-a) Technical Contribution  -- Texnika jixatdan xulosa
# - qaysi algaritmlar tanlandi
# - qanaqa feature enginering boldi
# - muammolar va yechimlar
# - oldingi va keyingi natijalar
# - oldingi va keyingio yaxshilangan natijani aniq berib ketish
# -- Misol uchun Besilen da natijam Accuracy score im  0.75%  edi keyin ensemble modeldan so`ng natija 0.87% ga oshdi
#
# # 2-b) Business Contribution -- Biznes jixatdan xulosa
# - foydalanuvchi yoki kompaniya qanday qiymat olishi mumkin
# - foyda, vaqt , muammo yechimi tarafdan afzal tamonlari
# - real natijalar bilan buni yozib ketish
# - berishingiz mumkin bo`lgan foydani yzib keting
#
#
#
# #  3) Qanday O`rnatish / Installation haqida
#
# ## Installation
# 1. Repo’ni klonlash: `git clone https://github.com/user/project.git`
# 2. Kerakli paketlarni o‘rnatish: `pip install -r requirements.txt`
#
# # 4) Qanday Ishlatish haqida
#
# ## Usage
# bash
# python main.py
#
# from project import module
# module.run()
#
# # 5) Funskiyalar yoki imkoniyatlar  haqida
#
# ## Features
# - Feature 1
# - Feature 2
# - Feature 3
#
# # 6) Litsenziya
#
# ## License
# MIT License © 2026
#
# # 7) Aloqa
#
# ## Contact
# - Email: example@mail.com
# - GitHub: [username](https://github.com/username)

# %% [markdown]
# # Emojilarni ReadMe.md faylga qo`shish
#
# - 🚀 Installation
# - 🔧 Features
# - ✅ Completed tasks
#
# ## 🚀 Technical Contribution
# - 🧪 Performed EDA using Pandas & Seaborn
# - 🔧 Applied ML models: Logistic Regression, Random Forest
# - ⚡ Optimized performance with hyperparameter tuning
#
# Emoji yaratish tartibi quyidagicha
# :rocket: O`rnatish

# %% [markdown]
# ✅ O`rnatish
# :gear: nastroyka
# :chart_with_upwards_trends:
