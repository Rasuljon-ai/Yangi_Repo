# %% [markdown]
# # Probabilistic Algoritmlar

# %% [markdown]
# # Ushbu algaritmlar ehtimollik nazariyasga asoslangan bo`ladi

# %% [markdown]
# # Tarif: Kiritilgan malumotlarni ehtimollik taqsimotiga asoslangan holda natijani bashorat qiladi

# %% [markdown]
# # qoshimcha: ushbu modellar statistik taxminlar va  ehtimolilik nazariyasiga asosan  ishlaydi

# %% [markdown]
# # Misollar:
# - Naive Bayes
# - Bayesian Networks

# %% [markdown]
# # Ishashiga misol : belgilariga qarab kasallikni taxmin qilish

# %% [markdown]
# # Neyron tarmoq ga asoslangan Algoritmlar

# %% [markdown]
# # Neural Network Based Models

# %% [markdown]
# # Insonning miya tuzilishidan ilhomlangan holda yaratilgan modellar bo`lib malumotlarda murakkab naqshlarni aniqlaydi

# %% [markdown]
# # Tasnif sababi: ular neyronlar orasidagi o`zaro bog`liqlikni ishlatib chiziqli bo`lmagan bo`gliqliklarni aniqlaydi

# %% [markdown]
# # Misol Algaritmlar :
# - CNN - Convolutional Neural Networks
# - RNN - Recurrent Neural Networks

# %% [markdown]
# # Algoritmlar
# - Liner Regression
# - Logistic Regression
# - Ridge Regression
# - Lasso Regression
# - Elastic Net
# - Decision Tree
# - Random Forest
# - Gradient Boosting
# - GBM
# - XGboost
# - LightGBM
# - Cat Boost
# - Ada Boost Extraa Trees
# - K_Neares Neighbours
# - Support Vector Machine
# - Naive Bayes
# - Guassian
# - Multinominal
# - Bernoulli
# - Bayesian Networks
# - Bagging
# - Stacking
# - Voting
# - Boostrap Aggregating

# %% [markdown]
# # Classification - bunda algaritmlar tasniflash muammolarini xal qiladi ya`ni obyektlarni oldindan belgilangan sinflarga ajratadi

# %% [markdown]
# # Algaritm tanlash asoslari
#
# - Kichik Dataset - Linear, SVM
#
# - Nonlinear Data - Tree Based
#
# - Text Data - Naive Bayes, Transformer
#
# - Katta Dataset - XGBoost, LightGBM
#
# - Real Time - Linear Modellar
#
# - Image / Audio -- CNN
