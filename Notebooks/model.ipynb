# %% [markdown]
# # Model - bu malumotlardan o`rganib , yangi malumotlar uchun bashorat qiladigan matematik tizim

# %% [markdown]
# # Model bu malumotdan o`rganib kelajakda qaror qabul qialdigan matematik aql

# %% [markdown]
# # Model Qanday o`rganadi
# 1) Modelga data beriladi
# 2) Model analiz qialdi
# 3) model taxmin qiladi
# 4) xatolik xisonblanadi (loss)
# 5) xatoga qarab o`zini yanada yaxshilaydi
# 6) shu jarayon qayta qayta takrorlanadi

# %% [markdown]
# # Model uchun mator sifatida bizga Algoritm kerak bo`ladi

# %% [markdown]
# # Algoritm  - bu muammoni yechish uchun ketma - ket, aniq va chekli qadamlar to`plami

# %% [markdown]
# # kiruvchi malumotni  olib oldindan belgilangan qoidalar asosida  uni qayta ishlab , natija chiqaradigan formal jarayon bu - Algoritm

# %% [markdown]
# # Algoritm quyidagi 5 ta xususiyatga ega bo`lishi kerak

# %% [markdown]
# - 1) Aniqlik - Har bir qadam tushunarli
# - 2) Cheklilik - oxiri mavjud bo`lishi
# - 3) Kirish - input qabul qilishi
# - 4) Chiqish - Output berishi
# - 5) Samaradorlik - Amalda yaxshi natija berishi

# %% [markdown]
# # Algoritm - reja:
# # Dastur - Amalga Oshiruvchi

# %% [markdown]
# # ML - da algoritm bu  model qanda yo`rganishini belgilan beruvchi matematik jarayon

# %% [markdown]
# # Algortim - organish qoidasi
# # model - o`rganilgan bilim

# %% [markdown]
# # Algoritm - qanday o`rganish
# # Model - nimani o`rgandi
# # AI -  shu bilimdan foydalanib qaror qabul qiladigan tizim

# %% [markdown]
# # ML Algoritmlari

# %% [markdown]
# # 1- SML ALgortimlari

# %% [markdown]
# # 2- UNS ML Algoritmlari

# %% [markdown]
# # 3-Semi Supervised Algoritmlari

# %% [markdown]
# # 4 - ReinForcement Algoritmlari

# %% [markdown]
# # 5 - Ensemble Algoritmlari

# %% [markdown]
# # 6 - Neural Network & Deep Learning Algoritmlari

# %% [markdown]
# # ML Algoritm Oilalari

# %% [markdown]
# # 1- Linear Based
# # 2- Tree  Based
# # 3- Distance Based
# # 4- SVM ==  Support vector Machine
# # 5- Ensemble Mathods -- Bagging/ Boosting/ Stacking // Voting

# %% [markdown]
# # Linear Based Algoritm

# %% [markdown]
# # --Ushbu algoritm  - malumotlardan kelib chiqib  chiziqli faraz asosida modelni yaratadi

# %% [markdown]
# # Algoritmlari
# - 1- Linear Regression -  cheksiz qiymatlar uchun SML Regression
# - 2- Logistic Regression -  binary classfication SML Classification
# - 3- Ridge / Lasso - Regularization bilan linear regression

# %% [markdown]
# # Afzalliklari
# - Oddiy
# - Tez
# - Natijani interpretatsiya qilish oson
#
# # Kamchiliklari :
# - chiziqli bo`lmagan malumotlar bilan ishlaganda yaxshi emas

# %%
# Misol

from sklearn.linear_model import LinearRegression

x = [[1], [2], [3], [4]]
y = [2, 4, 6, 8]
model = LinearRegression()
model.fit(x,y)
print(model.predict([[5]]))
# Out:
# [10.]
