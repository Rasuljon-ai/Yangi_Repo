# %% [markdown]
# # Imbalance Datasetlarda Sampling

# %%
import pandas as pd 
df = pd.read_csv(r"C:\Users\Rasulbek907\Desktop\Project_One\Data\Raw_Data\titanic.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df["Survived"].unique()
# Out:
# array([0, 1])

# %%
df["Survived"].nunique()
# Out:
# 2

# %%
df["Survived"].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %% [markdown]
# # target ustunida chiqayotgan natijadan har bitta class bo`yicha sonlar teng bo`lmasa bu Imbalance dataset deyiladi (Muvozanatsiz malumotlar to`plami)

# %% [markdown]
# # target ustunidagi qiymati kam bo`lgan classni - MINORITY deb nomlaymiz
# # qiymat jihatidan ko`p bo`lgan classni MAJORITY deb nomlaymiz

# %% [markdown]
# # Agarda Imbalance dataset bilan model trainin gqilinsa nimalar sodir b`oladi
# - kichik miqdordagi classlarni ignore qiladi
# - kichik miqdordagi classlar ustida past natija chiqadi
# - umumiy natija baland bo`lishi mumkin lekin biased perfortance bo`ladi  va bu overfittingga sabab bo`ladi

# %% [markdown]
# # YECHIMI

# %% [markdown]
# # 2 XIL YECHIMI MAVJUD

# %% [markdown]
# # 1- YECHIM BU MINORITY CLASSNI KO`PAYTIRISH == OVERSAMPLING

# %% [markdown]
# # 2-YECHIM MAJORITY CLASSNI KAMAYTIRISH == UNDERSAMPLING

# %% [markdown]
# # Sampling tenikalari (Overfsampling va Undersampling) - bu texnikalar classification tasklarda model generalization va fairness ni oshiradi

# %% [markdown]
# # Generalization - bu modelning umumiylik yoki umumlashtirish qobilyati
# # Fairness - bu modelning biror tarafga og`ishmay adolatli qaror qabul qilishi

# %% [markdown]
# # Oversampling

# %% [markdown]
# # Oversamplingda - kichik miqdordagi classlardagi qiymatlarni oshirish va katta miqdordagi classlar soniga yetkazish tushuniladi

# %% [markdown]
# # multi class bo`lsa u xolda eng ko`p class soniga qarab yetkaziladi, yani 1 dan 3 ta 0 dan 2ta 2 dan 8 ta bo`lsa 0 va 1 ni 8 taga yetkazamiz

# %% [markdown]
# # Oversampling Texnikalari
# - Random Oversampling
# - SMOTE
# - ADASYN

# %% [markdown]
# # Random Oversampling

# %% [markdown]
# # bunda ishlash prinsipi shunaqaki qiymatlarni duplicate qilish orqali ko`paytirib qo`yadi tanlab olganda randomli xolatda tanlaydi

# %% [markdown]
# # SMOTE

# %% [markdown]
# # buni ishlash prinsipi shunaqaki - (sythetic minority oversampling technique) - suniy qiymatlarni yaratish orqali qiymatlar qo`shadi

# %% [markdown]
# # ADASYN   - adaptive sythetic sampling

# %% [markdown]
# # bu texnika ham matematik jihatdan hisoblab toldirib beradi

# %% [markdown]
# from collections import Counter - ushbu counterni chaqirib SMOTE bilan birga ishlatamiz, chunki bu yerda counter sanab berich uchun kerak bo`ladi.
# # Qoida_SMOTE da qiymatlar oz bo`lsa k_neighbours=1 qiymati berib ketiladi
# # smote = SMOTE(random_state=42, k_neigbours=1)

# %% [markdown]
# # Undersampling Texnikalari
# - Random Undersampling
# - Cluster Centroids
# - Near Miss

# %% [markdown]
# # Random Undersampling

# %% [markdown]
# # Cluster Centroids

# %% [markdown]
# # ishlashi quyidagicha - majority classning sonidan keib chiqib  ularni o`sha songa bo`lib p`rtacha qiymatini oladi va o`chiradi

# %% [markdown]
# # Near Miss

# %% [markdown]
# # ishlash tartibi - majortiy classdan ninority classgacha masofani o`lchaydi  va xosisoblab kamaytiradi

# %% [markdown]
# # Oversampling texnikasini "+ " tamonlari
#
# - datani orginalligini saqlab qoladi
# - minority classlarni ulushini oshiradi
# - minority classning ham predict bo`lishuini ehtimolini oshiradi
# - yetarli computing resurslar bilan yaxshi natija beradi

# %% [markdown]
# # Oversampling texnikasini " -  " tamonlari
#
# - overfittinggga sabab bol`ishi mumkin
# - training time oshib ketadi

# %% [markdown]
# # Undersampling texnikasini " + " tamonlari
#
# - training tezroq bo`ladi
# - sodda va  effektive

# %% [markdown]
# # Undersampling texnikasini " - " tamonlari
#
# - muhim bo`lgan datalarni yo`qotishga sabab bo`lishi mumkin
# - underfittingga sabab bo`lishi mumkin

# %% [markdown]
# # Sampling Amaliyot

# %%
import pandas as pd 
import seaborn as sns 

df = sns.load_dataset("titanic")

df = df[["survived", "pclass", "sex", "age", "fare"]]
df["age"].fillna(df["age"].median(), inplace=True)
df["sex"] = df["sex"].map({"male":0, "female":1})

x = df.drop("survived", axis=1)
y = df["survived"]
# Out:
# C:\maya_temp\ipykernel_11312\2536976337.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["age"].fillna(df["age"].median(), inplace=True)

# %%
print(y.value_counts())
# Out:
# survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %% [markdown]
# # Random Oversampling

# %%
# !pip install imblearn
# Out:
# ...
#   Using cached imblearn-0.0-py2.py3-none-any.whl.metadata (355 bytes)
# ...
# Using cached imblearn-0.0-py2.py3-none-any.whl (1.9 kB)
# ...
#
#    ---------------------------------------- 0/3 [sklearn-compat]
#    ------------- -------------------------- 1/3 [imbalanced-learn]
#    ------------- -------------------------- 1/3 [imbalanced-learn]
#    ------------- -------------------------- 1/3 [imbalanced-learn]
#    ------------- -------------------------- 1/3 [imbalanced-learn]
#    ------------- -------------------------- 1/3 [imbalanced-learn]
#    ------------- -------------------------- 1/3 [imbalanced-learn]
#    ------------- -------------------------- 1/3 [imbalanced-learn]
#    ------------- -------------------------- 1/3 [imbalanced-learn]
#    ------------- -------------------------- 1/3 [imbalanced-learn]
#    ------------- -------------------------- 1/3 [imbalanced-learn]
#    ---------------------------------------- 3/3 [imblearn]
#
# ...

# %%
from imblearn.over_sampling import RandomOverSampler

ros = RandomOverSampler(random_state=42)

x_ros, y_ros = ros.fit_resample(x, y)

print(y_ros.value_counts())
# Out:
# survived
# 0    549
# 1    549
# Name: count, dtype: int64

# %% [markdown]
# # SMOTE

# %%
from imblearn.over_sampling import SMOTE

smote = SMOTE(random_state=42, k_neighbors=5)

x_smote, y_smote = smote.fit_resample(x, y)

print(y_smote.value_counts())
# Out:
# survived
# 0    549
# 1    549
# Name: count, dtype: int64

# %% [markdown]
# # ADASYN

# %%
from imblearn.over_sampling import ADASYN

adasyn = ADASYN(random_state=42)

x_adasyn, y_adasyn = adasyn.fit_resample(x, y)

print(y_adasyn.value_counts())
# Out:
# survived
# 1    571
# 0    549
# Name: count, dtype: int64

# %% [markdown]
# # Random UnderSampling

# %%
from imblearn.under_sampling import RandomUnderSampler

rus = RandomUnderSampler(random_state=42)

x_rus, y_rus = rus.fit_resample(x, y)

print(y_rus.value_counts())
# Out:
# survived
# 0    342
# 1    342
# Name: count, dtype: int64

# %% [markdown]
# # Cluster Centroids

# %%
from imblearn.under_sampling import ClusterCentroids

cc = ClusterCentroids(random_state=42)

x_cc, y_cc = cc.fit_resample(x, y)

print(y_cc.value_counts())
# Out:
# survived
# 0    342
# 1    342
# Name: count, dtype: int64

# %% [markdown]
# # Near Miss

# %%
from imblearn.under_sampling import NearMiss

nearmiss = NearMiss(version=1)

x_nearmiss, y_nearmiss = nearmiss.fit_resample(x, y)

print(y_nearmiss.value_counts())
# Out:
# survived
# 0    342
# 1    342
# Name: count, dtype: int64

# %% [markdown]
# | Holat              | Tavsiya           |
# | ------------------ | ----------------- |
# | Dataset kichik     | SMOTE             |
# | Juda katta dataset | Undersampling     |
# | Shovqin kam        | ADASYN            |
# | Tez baseline       | RandomOverSampler |
# | Klasslar yaqin     | NearMiss          |
# | Katta majority     | ClusterCentroids  |
